# %% [markdown]
# #                                 Expermienting Newton's Law of cooling

# %% [markdown]
# The temperature in three beakers that contain water is measured as they cooled from boiling.  The purposes of this experiment are determining if the Newton’s Law of Cooling is fitting well with realdata and investigating the effect of changing the volume of water being cooled. Using three beakers of water for this experiment.  The first hold 100 ml of water,the second 300 ml, and the third 800 ml. Originally, all of the beakers hold waterat 100C. Each beaker had its own thermometer and the thermometers are keptin  the  beakers  between  measurements  so  there  would  be  no  temperature  lag.The temperature of the water in each beaker is measured every minute, alwaysin the same order.  The temperature of the surrounding for this investigation is23C.The  temperature  is  measured  every  minute  for  35  minutes  and  then  every  5 minutes for the remainder of one hour.

# %%
import numpy as np
import pylab
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
excelfile = pd.read_excel(r'C:\Users\Nati\Documents\Untitled Folder\mfcassignemnt.xlsx',skiprows=2)
excelfile = excelfile[["Time (min)","100 ml Temperature °C","300 ml Temperature °C","800 ml Temperature °C","Theoretical 100ml","Theoritical 300ml","Theoritical 800 ml"]]
plt.plot(excelfile['Time (min)'], excelfile['100 ml Temperature °C'], 'b.-',label= '100 ml Temperature °C')
plt.plot(excelfile['Time (min)'], excelfile['300 ml Temperature °C'], 'g.-',label= '300 ml Temperature °C' )
plt.plot(excelfile['Time (min)'], excelfile['800 ml Temperature °C'], 'y.-',label= '800 ml Temperature °C')
plt.xlabel('Time (min)')
plt.ylabel('Temperature °C')
plt.title('Graph of Temperature against the Time(min)', fontdict={'fontsize': 11})
plt.legend()

# %%
plt.plot(excelfile['Time (min)'], excelfile['100 ml Temperature °C'], 'b.-',label= '100 ml Temperature °C')
plt.plot(excelfile['Time (min)'], excelfile['Theoretical 100ml'], 'r.-',label= 'Theoretical 100ml' )
plt.xlabel('Time (min)')
plt.ylabel('Temperature °C')
plt.title('Graph of Temperature against the Time(min)', fontdict={'fontsize': 11})
plt.legend()

# %%
plt.plot(excelfile['Time (min)'], excelfile['300 ml Temperature °C'], 'g.-',label= '300 ml Temperature °C')
plt.plot(excelfile['Time (min)'], excelfile['Theoritical 300ml'], 'r.-',label= 'Theoritical 300ml' )
plt.xlabel('Time (min)')
plt.ylabel('Temperature °C')
plt.title('Graph of Temperature against the Time(min)', fontdict={'fontsize': 11})
plt.legend()

# %%
plt.plot(excelfile['Time (min)'], excelfile['800 ml Temperature °C'], 'y.-',label= '800 ml Temperature °C')
plt.plot(excelfile['Time (min)'], excelfile['Theoritical 800 ml'], 'r.-',label= 'Theoritical 800 ml' )
plt.xlabel('Time (min)')
plt.ylabel('Temperature °C')
plt.title('Graph of Temperature against the Time(min)', fontdict={'fontsize': 11})
plt.legend()

# %%
x = np.linspace(0,4,100) 
out_array = np.exp(x) 
out_array2 = np.exp(1.1*x)
out_array3 = np.exp(1.2*x)
out_array4 = np.exp(1.3*x)
# compose plot
pylab.plot(x,out_array, label= 'e^x')
pylab.plot(x,out_array2, label= 'e^1.1x') 
pylab.plot(x,out_array3, label= 'e^1.2x') 
pylab.plot(x,out_array4, label= 'e^1.3x') 
pylab.title('Relationship between k and T(t)', fontdict={'fontsize': 11})
pylab.legend()
